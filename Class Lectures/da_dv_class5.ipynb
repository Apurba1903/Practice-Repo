# %%
import pandas as pd

# %%
df = pd.read_csv("houserentdhaka.csv")

# %%
df
# Out:
#        Unnamed: 0                                           Location  \
# 0               0                    Block H, Bashundhara R-A, Dhaka
# 1               1                           Farmgate, Tejgaon, Dhaka
# 2               2  Block B, Nobodoy Housing Society, Mohammadpur,...
# 3               3                          Gulshan 1, Gulshan, Dhaka
# 4               4                                   Baridhara, Dhaka
# ...           ...                                                ...
# 28795        4795                           Section 2, Mirpur, Dhaka
# 28796        4796                    Block F, Bashundhara R-A, Dhaka
# 28797        4797         RK Mission Road, Gopibag, Motijheel, Dhaka
# 28798        4798                Ullan, West Rampura, Rampura, Dhaka
# 28799        4799                               Vatara, Badda, Dhaka
#
#              Area  Bed  Bath        Price
# 0      1,600 sqft  3.0   3.0  20 Thousand
# 1        900 sqft  2.0   2.0  20 Thousand
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                                           Location        Area  \
# 0           0                    Block H, Bashundhara R-A, Dhaka  1,600 sqft
# 1           1                           Farmgate, Tejgaon, Dhaka    900 sqft
# 2           2  Block B, Nobodoy Housing Society, Mohammadpur,...  1,250 sqft
# 3           3                          Gulshan 1, Gulshan, Dhaka  2,200 sqft
# 4           4                                   Baridhara, Dhaka         NaN
#
#    Bed  Bath        Price
# 0  3.0   3.0  20 Thousand
# 1  2.0   2.0  20 Thousand
# 2  3.0   3.0  18 Thousand
# 3  3.0   4.0  75 Thousand
# 4  3.0   3.0  75 Thousand

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df
# Out:
#                                                 Location        Area  Bed  \
# 0                        Block H, Bashundhara R-A, Dhaka  1,600 sqft  3.0
# 1                               Farmgate, Tejgaon, Dhaka    900 sqft  2.0
# 2      Block B, Nobodoy Housing Society, Mohammadpur,...  1,250 sqft  3.0
# 3                              Gulshan 1, Gulshan, Dhaka  2,200 sqft  3.0
# 4                                       Baridhara, Dhaka         NaN  3.0
# ...                                                  ...         ...  ...
# 28795                           Section 2, Mirpur, Dhaka  1,400 sqft  3.0
# 28796                    Block F, Bashundhara R-A, Dhaka  1,400 sqft  3.0
# 28797         RK Mission Road, Gopibag, Motijheel, Dhaka  1,250 sqft  3.0
# 28798                Ullan, West Rampura, Rampura, Dhaka  1,900 sqft  3.0
# 28799                               Vatara, Badda, Dhaka  1,150 sqft  3.0
#
#        Bath        Price
# 0       3.0  20 Thousand
# 1       2.0  20 Thousand
# ...

# %%
df.columns
# Out:
# Index(['Location', 'Area', 'Bed', 'Bath', 'Price'], dtype='object')

# %%
# df = df[[
#     'Location', 
#     'Area', 
#     'Bed', 
#     #'Bath', 
#     'Price'
# ]]

# %%
df
# Out:
#                                                 Location        Area  Bed  \
# 0                        Block H, Bashundhara R-A, Dhaka  1,600 sqft  3.0
# 1                               Farmgate, Tejgaon, Dhaka    900 sqft  2.0
# 2      Block B, Nobodoy Housing Society, Mohammadpur,...  1,250 sqft  3.0
# 3                              Gulshan 1, Gulshan, Dhaka  2,200 sqft  3.0
# 4                                       Baridhara, Dhaka         NaN  3.0
# ...                                                  ...         ...  ...
# 28795                           Section 2, Mirpur, Dhaka  1,400 sqft  3.0
# 28796                    Block F, Bashundhara R-A, Dhaka  1,400 sqft  3.0
# 28797         RK Mission Road, Gopibag, Motijheel, Dhaka  1,250 sqft  3.0
# 28798                Ullan, West Rampura, Rampura, Dhaka  1,900 sqft  3.0
# 28799                               Vatara, Badda, Dhaka  1,150 sqft  3.0
#
#        Bath        Price
# 0       3.0  20 Thousand
# 1       2.0  20 Thousand
# ...

# %%
df = df.rename(columns={'Bath':'Bathroom', 'Bed':'Bedroom'})

# %%
df.head()
# Out:
#                                             Location        Area  Bedroom  \
# 0                    Block H, Bashundhara R-A, Dhaka  1,600 sqft      3.0
# 1                           Farmgate, Tejgaon, Dhaka    900 sqft      2.0
# 2  Block B, Nobodoy Housing Society, Mohammadpur,...  1,250 sqft      3.0
# 3                          Gulshan 1, Gulshan, Dhaka  2,200 sqft      3.0
# 4                                   Baridhara, Dhaka         NaN      3.0
#
#    Bathroom        Price
# 0       3.0  20 Thousand
# 1       2.0  20 Thousand
# 2       3.0  18 Thousand
# 3       4.0  75 Thousand
# 4       3.0  75 Thousand

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28800 entries, 0 to 28799
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Location  28798 non-null  object
#  1   Area      28796 non-null  object
#  2   Bedroom   28794 non-null  float64
#  3   Bathroom  28796 non-null  float64
#  4   Price     28797 non-null  object
# dtypes: float64(2), object(3)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# Location    2
# Area        4
# Bedroom     6
# Bathroom    4
# Price       3
# dtype: int64

# %%
df['Location'].value_counts()
# Out:
# Location
# Mohammadpur, Dhaka                     757
# Mirpur, Dhaka                          556
# Block D, Section 12, Mirpur, Dhaka     417
# Dhanmondi, Dhaka                       414
# Block E, Section 12, Mirpur, Dhaka     411
#                                       ...
# 2nd Lane, Gopibag, Motijheel, Dhaka      1
# Block D2, Section 10, Mirpur, Dhaka      1
# Block D, Aftab Nagar, Dhaka              1
# Panthapath, Kathalbagan, Dhaka           1
# Chowdhury Bazar, Lalbagh, Dhaka          1
# Name: count, Length: 730, dtype: int64

# %%
df[df['Location'].isnull()]
# Out:
#     Location        Area  Bedroom  Bathroom        Price
# 526      NaN  1,650 sqft      3.0       3.0  28 Thousand
# 558      NaN  1,800 sqft      3.0       3.0  28 Thousand

# %%
df.drop([526,558], inplace=True)

# %%
df[df['Area'].isnull()]
# Out:
#                       Location Area  Bedroom  Bathroom        Price
# 4             Baridhara, Dhaka  NaN      3.0       3.0  75 Thousand
# 76    East Badda, Badda, Dhaka  NaN      3.0       3.0  20 Thousand
# 269  Block J, Baridhara, Dhaka  NaN      4.0       5.0  70 Thousand
# 490  Gulshan 1, Gulshan, Dhaka  NaN      3.0       3.0  85 Thousand

# %%
df.drop([4,76,269, 490], inplace=True)

# %%
df[df['Area'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Location, Area, Bedroom, Bathroom, Price]
# Index: []

# %%
df['Price'] = df['Price'].str.extract(r'(\d+)').astype('int64') * 1000
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df['Price'] = df['Price'].str.extract(r'(\d+)').astype('int64') * 1000
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py:6662, in NDFrame.astype(self, dtype, copy, errors)
#    6656     results = [
#    6657         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6658     ]
#    6660 else:
#    6661     # else, only a single dtype is given
# -> 6662     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6663     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6664     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
# ...

# %%
df.head()
# Out:
#                                             Location        Area  Bedroom  \
# 0                    Block H, Bashundhara R-A, Dhaka  1,600 sqft        3
# 1                           Farmgate, Tejgaon, Dhaka    900 sqft        2
# 2  Block B, Nobodoy Housing Society, Mohammadpur,...  1,250 sqft        3
# 3                          Gulshan 1, Gulshan, Dhaka  2,200 sqft        3
# 4                                   Baridhara, Dhaka  2,200 sqft        3
#
#    Bathroom  Price
# 0         3  20000
# 1         2  20000
# 2         3  18000
# 3         4  75000
# 4         3  75000

# %%
#df.Area = df.Area.str.strip().str.replace(",", "").str.replace(" sqft", "").str.strip().astype('int64')

df.Area = df.Area.str.strip().str.replace(",", "").str.split(" ").str[0].str.strip().astype('int64')

#df.Area = df.Area.str.strip().str.replace(",", "").str.extract(r'(\d+)').astype('int64')

# %%
df.rename(columns={'Area': 'Area (sqft)'}, inplace=True)

# %%
df.head()
# Out:
#                                             Location  Area (sqft)  Bedroom  \
# 0                    Block H, Bashundhara R-A, Dhaka         1600        3
# 1                           Farmgate, Tejgaon, Dhaka          900        2
# 2  Block B, Nobodoy Housing Society, Mohammadpur,...         1250        3
# 3                          Gulshan 1, Gulshan, Dhaka         2200        3
# 4                                   Baridhara, Dhaka         2200        3
#
#    Bathroom  Price
# 0         3  20000
# 1         2  20000
# 2         3  18000
# 3         4  75000
# 4         3  75000

# %%
df.dtypes
# Out:
# Location       object
# Area (sqft)     int64
# Bedroom         int64
# Bathroom        int64
# Price           int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28800 entries, 0 to 28799
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Location     28800 non-null  object
#  1   Area (sqft)  28800 non-null  int64
#  2   Bedroom      28800 non-null  int64
#  3   Bathroom     28800 non-null  int64
#  4   Price        28800 non-null  int64
# dtypes: int64(4), object(1)
# memory usage: 1.1+ MB
